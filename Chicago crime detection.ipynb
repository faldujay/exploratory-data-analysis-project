# %% [markdown]
# ### Author:- Faldu jay
# #### Email :- jay.faldu928@gmail.com

# %% [markdown]
# # Exploratory Data Analysis Project

# %% [markdown]
# # Chicago crime detection

# %% [markdown]
# In this project assume that you are hired as an Analyst by Chicago Police. They have been maintaining a database of "motor vehicle theft" (sometimes referred to as grand theft auto) since last few years. This is the act of stealing, or attempting to steal, a car.
#
# Due to increasing crimes, they want to make use of data to strategize better to maintain peace and order in their State. As a part of their Analyst team, you have been posed with some questions given below. Use your gained Data Analysis skills to answer these questions and help of the Police Department!
#
# we are going toanssertain question in this project which give us some insite about this data.
#
# Also by this technique we can understand and analyse dataset according to our need.
#
# Every question is consider as goal that from data set we need that information and see the procedure to get this information. we get other similler kindof information from data set by following this steps.

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### read data from dataset

# %%
# change destination according to your data

df = pd.read_csv('Chicago_crime_Detective.csv',parse_dates=['Date'],infer_datetime_format=True)
df
# Out:
# C:\Users\Administrator\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (7,8) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Unnamed: 0       ID                Date  \
# 0                0  8951354 2012-12-31 23:15:00
# 1                1  8951141 2012-12-31 22:00:00
# 2                2  8952745 2012-12-31 22:00:00
# 3                3  8952223 2012-12-31 22:00:00
# 4                4  8951608 2012-12-31 21:30:00
# ...            ...      ...                 ...
# 191636      191636  1310068 2001-01-01 00:05:00
# 191637      191637  1313404 2001-01-01 00:01:00
# 191638      191638  1313442 2001-01-01 00:01:00
# 191639      191639  1563324 2001-01-01 00:01:00
# 191640      191640  1310463 2001-01-01 00:01:00
#
#                   LocationDescription  Arrest  Domestic  Beat District  \
# 0                              STREET   False     False   623        6
# 1                              STREET   False     False  1213       12
# 2       RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# 3                              STREET   False     False   724        7
# 4                              STREET   False     False   211        2
# ...                               ...     ...       ...   ...      ...
# 191636                         STREET   False     False  1123      NaN
# 191637                         STREET   False     False  2023      NaN
# 191638                         STREET   False     False   911      NaN
# 191639                         STREET   False     False  1712      NaN
# 191640                         STREET   False     False  1911      NaN
#
#        CommunityArea  Year
# 0                 69  2012
# 1                 24  2012
# 2                 11  2012
# 3                 67  2012
# 4                 35  2012
# ...              ...   ...
# 191636           NaN  2001
# 191637           NaN  2001
# 191638           NaN  2001
# 191639           NaN  2001
# 191640           NaN  2001
#
# [191641 rows x 10 columns]

# %%
df.Date[0]      # converted in time sucessfully
# Out:
# Timestamp('2012-12-31 23:15:00')

# %%
df.Date[0].to_pydatetime().month
# Out:
# 12

# %% [markdown]
# ## Data Columns details:
# 1. ID: a unique identifier for each observation.
#
# 2. Date: the date the crime occurred.
# LocationDescription: the location where the crime occurred.
#
# 3. Arrest: whether or not an arrest was made for the crime (TRUE if an arrest was made, and FALSE if an arrest was not made).
#
# 4. Domestic: whether or not the crime was a domestic crime, meaning that it was committed against a family member (TRUE if it was domestic, and FALSE if it was not domestic).
#
# 5. Beat: the area, or "beat" in which the crime occurred. This is the smallest regional division defined by the Chicago police department.
#
# 6. District: the police district in which the crime occured. Each district is composed of many beats, and are defined by the Chicago Police Department.
#
# 7. CommunityArea: the community area in which the crime occurred. Since the 1920s, Chicago has been divided into what are called "community areas", of which there are now 77. The community areas were devised in an attempt to create socially homogeneous regions.
#
# 8. Year: the year in which the crime occurred.
# Latitude: the latitude of the location at which the crime occurred.

# %% [markdown]
# ### adding column of month

# %%
df.dtypes
# Out:
# Unnamed: 0                      int64
# ID                              int64
# Date                   datetime64[ns]
# LocationDescription            object
# Arrest                           bool
# Domestic                         bool
# Beat                            int64
# District                       object
# CommunityArea                  object
# Year                            int64
# dtype: object

# %%
month=[]
for i in range(len(df.Date)):
    month.append(df.Date[i].to_pydatetime().month)

# %%
df.insert(10,'Month',month)

# %%
df
# Out:
#         Unnamed: 0       ID                Date  \
# 0                0  8951354 2012-12-31 23:15:00
# 1                1  8951141 2012-12-31 22:00:00
# 2                2  8952745 2012-12-31 22:00:00
# 3                3  8952223 2012-12-31 22:00:00
# 4                4  8951608 2012-12-31 21:30:00
# ...            ...      ...                 ...
# 191636      191636  1310068 2001-01-01 00:05:00
# 191637      191637  1313404 2001-01-01 00:01:00
# 191638      191638  1313442 2001-01-01 00:01:00
# 191639      191639  1563324 2001-01-01 00:01:00
# 191640      191640  1310463 2001-01-01 00:01:00
#
#                   LocationDescription  Arrest  Domestic  Beat District  \
# 0                              STREET   False     False   623        6
# 1                              STREET   False     False  1213       12
# 2       RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# 3                              STREET   False     False   724        7
# 4                              STREET   False     False   211        2
# ...                               ...     ...       ...   ...      ...
# 191636                         STREET   False     False  1123      NaN
# 191637                         STREET   False     False  2023      NaN
# 191638                         STREET   False     False   911      NaN
# 191639                         STREET   False     False  1712      NaN
# 191640                         STREET   False     False  1911      NaN
#
#        CommunityArea  Year  Month
# 0                 69  2012     12
# 1                 24  2012     12
# 2                 11  2012     12
# 3                 67  2012     12
# 4                 35  2012     12
# ...              ...   ...    ...
# 191636           NaN  2001      1
# 191637           NaN  2001      1
# 191638           NaN  2001      1
# 191639           NaN  2001      1
# 191640           NaN  2001      1
#
# [191641 rows x 11 columns]

# %%
df.describe(include=['object'])
# Out:
#        LocationDescription  District CommunityArea
# count               191641  148589.0        167038
# unique                  78      50.0           157
# top                 STREET       8.0            25
# freq                156564    7462.0          6832

# %% [markdown]
# ###
#
#
#
# ### 1.)  What is the Month and Year of the median date in our dataset?

# %%
df['Unnamed: 0'].median()
# Out:
# 95820.0

# %%
df[df['Unnamed: 0'] == df['Unnamed: 0'].median()]
# Out:
#        Unnamed: 0       ID                Date LocationDescription  Arrest  \
# 95820       95820  4752501 2006-05-21 12:30:00              STREET   False
#
#        Domestic  Beat District CommunityArea  Year  Month
# 95820     False   725        7            67  2006      5

# %%
df
# Out:
#         Unnamed: 0       ID                Date  \
# 0                0  8951354 2012-12-31 23:15:00
# 1                1  8951141 2012-12-31 22:00:00
# 2                2  8952745 2012-12-31 22:00:00
# 3                3  8952223 2012-12-31 22:00:00
# 4                4  8951608 2012-12-31 21:30:00
# ...            ...      ...                 ...
# 191636      191636  1310068 2001-01-01 00:05:00
# 191637      191637  1313404 2001-01-01 00:01:00
# 191638      191638  1313442 2001-01-01 00:01:00
# 191639      191639  1563324 2001-01-01 00:01:00
# 191640      191640  1310463 2001-01-01 00:01:00
#
#                   LocationDescription  Arrest  Domestic  Beat District  \
# 0                              STREET   False     False   623        6
# 1                              STREET   False     False  1213       12
# 2       RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# 3                              STREET   False     False   724        7
# 4                              STREET   False     False   211        2
# ...                               ...     ...       ...   ...      ...
# 191636                         STREET   False     False  1123      NaN
# 191637                         STREET   False     False  2023      NaN
# 191638                         STREET   False     False   911      NaN
# 191639                         STREET   False     False  1712      NaN
# 191640                         STREET   False     False  1911      NaN
#
#        CommunityArea  Year  Month
# 0                 69  2012     12
# 1                 24  2012     12
# 2                 11  2012     12
# 3                 67  2012     12
# 4                 35  2012     12
# ...              ...   ...    ...
# 191636           NaN  2001      1
# 191637           NaN  2001      1
# 191638           NaN  2001      1
# 191639           NaN  2001      1
# 191640           NaN  2001      1
#
# [191641 rows x 11 columns]

# %% [markdown]
# ###
#
#
#
#
#
# ### 2.)  In which month did the lowest motor vehicle thefts occur?

# %%
df_month=df.groupby(['Month'])

# %%
df_month.count().ID
# Out:
# Month
# 1     16047
# 2     13511
# 3     15758
# 4     15280
# 5     16035
# 6     16002
# 7     16801
# 8     16572
# 9     16060
# 10    17086
# 11    16063
# 12    16426
# Name: ID, dtype: int64

# %%
df_month.ID.count().plot(kind='bar',figsize=(5,7))
plt.xlabel('month')
plt.ylabel('number of crime made')
# Out:
# Text(0, 0.5, 'number of crime made')

# %% [markdown]
# #### Minimum crime in month :- February - 13511

# %%
df_month_as_index =df.set_index(['Month'])  

# set month as index (its done for count frequancy of month) it's 2nd method to give ansof the above question

# %%
df_month_as_index.index.value_counts()  

# show frequancy of month, we can see less frequent month as february
# Out:
# 10    17086
# 7     16801
# 8     16572
# 12    16426
# 11    16063
# 9     16060
# 1     16047
# 5     16035
# 6     16002
# 3     15758
# 4     15280
# 2     13511
# Name: Month, dtype: int64

# %%
df_month_as_index.index.value_counts().plot(kind='bar',figsize=(5,7))
plt.xlabel('month')
plt.ylabel('number of crime made')
# Out:
# Text(0, 0.5, 'number of crime made')

# %% [markdown]
# ###
#
#
#
#
#
#
# ### 3.)  On which weekday did most motor vehicle thefts occur?

# %%
df
# Out:
#         Unnamed: 0       ID                Date  \
# 0                0  8951354 2012-12-31 23:15:00
# 1                1  8951141 2012-12-31 22:00:00
# 2                2  8952745 2012-12-31 22:00:00
# 3                3  8952223 2012-12-31 22:00:00
# 4                4  8951608 2012-12-31 21:30:00
# ...            ...      ...                 ...
# 191636      191636  1310068 2001-01-01 00:05:00
# 191637      191637  1313404 2001-01-01 00:01:00
# 191638      191638  1313442 2001-01-01 00:01:00
# 191639      191639  1563324 2001-01-01 00:01:00
# 191640      191640  1310463 2001-01-01 00:01:00
#
#                   LocationDescription  Arrest  Domestic  Beat District  \
# 0                              STREET   False     False   623        6
# 1                              STREET   False     False  1213       12
# 2       RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# 3                              STREET   False     False   724        7
# 4                              STREET   False     False   211        2
# ...                               ...     ...       ...   ...      ...
# 191636                         STREET   False     False  1123      NaN
# 191637                         STREET   False     False  2023      NaN
# 191638                         STREET   False     False   911      NaN
# 191639                         STREET   False     False  1712      NaN
# 191640                         STREET   False     False  1911      NaN
#
#        CommunityArea  Year  Month
# 0                 69  2012     12
# 1                 24  2012     12
# 2                 11  2012     12
# 3                 67  2012     12
# 4                 35  2012     12
# ...              ...   ...    ...
# 191636           NaN  2001      1
# 191637           NaN  2001      1
# 191638           NaN  2001      1
# 191639           NaN  2001      1
# 191640           NaN  2001      1
#
# [191641 rows x 11 columns]

# %%
df.Date[0].to_pydatetime().weekday()  # return weekday in timestamp
# Out:
# 0

# %%
# make a list of weekday of all entry in df and add as column in data frame

weekday = []
for i in range(len(df.Date)):
    weekday.append(df.Date[i].to_pydatetime().weekday())

df.insert(11,'weekday',weekday)

df.head()
# Out:
#    Unnamed: 0       ID                Date            LocationDescription  \
# 0           0  8951354 2012-12-31 23:15:00                         STREET
# 1           1  8951141 2012-12-31 22:00:00                         STREET
# 2           2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 3           3  8952223 2012-12-31 22:00:00                         STREET
# 4           4  8951608 2012-12-31 21:30:00                         STREET
#
#    Arrest  Domestic  Beat District CommunityArea  Year  Month  weekday
# 0   False     False   623        6            69  2012     12        0
# 1   False     False  1213       12            24  2012     12        0
# 2   False     False  1622       16            11  2012     12        0
# 3   False     False   724        7            67  2012     12        0
# 4   False     False   211        2            35  2012     12        0

# %%
weekday_as_index = df.set_index(['weekday'])
weekday_as_index.head()
# Out:
#          Unnamed: 0       ID                Date  \
# weekday
# 0                 0  8951354 2012-12-31 23:15:00
# 0                 1  8951141 2012-12-31 22:00:00
# 0                 2  8952745 2012-12-31 22:00:00
# 0                 3  8952223 2012-12-31 22:00:00
# 0                 4  8951608 2012-12-31 21:30:00
#
#                    LocationDescription  Arrest  Domestic  Beat District  \
# weekday
# 0                               STREET   False     False   623        6
# 0                               STREET   False     False  1213       12
# 0        RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# 0                               STREET   False     False   724        7
# 0                               STREET   False     False   211        2
#
#         CommunityArea  Year  Month
# weekday
# 0                  69  2012     12
# 0                  24  2012     12
# 0                  11  2012     12
# 0                  67  2012     12
# 0                  35  2012     12

# %%
weekday_as_index.index.value_counts()
# Out:
# 4    29284
# 2    27416
# 0    27397
# 3    27319
# 5    27118
# 1    26791
# 6    26316
# Name: weekday, dtype: int64

# %% [markdown]
# #### Ans :- hear we can see that weekday 4 means 'friday' ouucred at most frequency

# %%
weekday_as_index.index.value_counts().plot(kind='bar',figsize=(5,7))
plt.xlabel('weekdays:- \n 0-monday & 6-sunday')
plt.ylabel('number of crime made')
# Out:
# Text(0, 0.5, 'number of crime made')

# %% [markdown]
# ###
#
# ### 4.)   Each observation in the dataset represents a motor vehicle theft, and the Arrest variable indicates whether an arrest was later made for this theft. Which month has the largest number of motor vehicle thefts for which an arrest was made?

# %%
df_arrestmade = df_month_as_index[df_month_as_index.Arrest==True]
df_arrestmade.head()
# Out:
#        Unnamed: 0       ID                Date LocationDescription  Arrest  \
# Month
# 12              5  8950793 2012-12-31 20:30:00              STREET    True
# 12              8  8951802 2012-12-31 19:00:00              STREET    True
# 12             13  8950570 2012-12-31 16:20:00         GAS STATION    True
# 12             47  8949895 2012-12-30 19:46:00               ALLEY    True
# 12             59  8949557 2012-12-30 15:00:00              STREET    True
#
#        Domestic  Beat District CommunityArea  Year
# Month
# 12        False  2521       25            19  2012
# 12        False  1021       10            29  2012
# 12        False   825        8            66  2012
# 12        False  2512       25            18  2012
# 12        False  2535       25            23  2012

# %%
df_arrestmade.index.value_counts()
# Out:
# 1     1435
# 12    1397
# 10    1342
# 8     1329
# 7     1324
# 3     1298
# 11    1256
# 4     1252
# 9     1248
# 2     1238
# 6     1230
# 5     1187
# Name: Month, dtype: int64

# %% [markdown]
# #### Ans :- fromabove resulte we can say that in 'JANUARY' month most arrest was made

# %% [markdown]
# ###
#
#
#
#
# ### 5.)   show the crime data according to Year

# %%
year_as_index = df.set_index('Year')
year_as_index.head()
# Out:
#       Unnamed: 0       ID                Date            LocationDescription  \
# Year
# 2012           0  8951354 2012-12-31 23:15:00                         STREET
# 2012           1  8951141 2012-12-31 22:00:00                         STREET
# 2012           2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 2012           3  8952223 2012-12-31 22:00:00                         STREET
# 2012           4  8951608 2012-12-31 21:30:00                         STREET
#
#       Arrest  Domestic  Beat District CommunityArea  Month  weekday
# Year
# 2012   False     False   623        6            69     12        0
# 2012   False     False  1213       12            24     12        0
# 2012   False     False  1622       16            11     12        0
# 2012   False     False   724        7            67     12        0
# 2012   False     False   211        2            35     12        0

# %%
year_count=year_as_index.groupby('Year').count()
year_count
# Out:
#       Unnamed: 0     ID   Date  LocationDescription  Arrest  Domestic   Beat  \
# Year
# 2001       20669  20669  20669                20669   20669     20669  20669
# 2002       18753  18753  18753                18753   18753     18753  18753
# 2003       16657  16657  16657                16657   16657     16657  16657
# 2004       16862  16862  16862                16862   16862     16862  16862
# 2005       16484  16484  16484                16484   16484     16484  16484
# 2006       16098  16098  16098                16098   16098     16098  16098
# 2007       14280  14280  14280                14280   14280     14280  14280
# 2008       14445  14445  14445                14445   14445     14445  14445
# 2009       12167  12167  12167                12167   12167     12167  12167
# 2010       15497  15497  15497                15497   15497     15497  15497
# 2011       15637  15637  15637                15637   15637     15637  15637
# 2012       14092  14092  14092                14092   14092     14092  14092
#
#       District  CommunityArea  Month  weekday
# Year
# 2001       122            586  20669    20669
# 2002       494          14236  18753    18753
# 2003     12977          16657  16657    16657
# 2004     16824          16861  16862    16862
# 2005     16403          16484  16484    16484
# 2006     16069          16097  16098    16098
# 2007     14271          14280  14280    14280
# 2008     14280          14445  14445    14445
# 2009     12040          12166  12167    12167
# 2010     15484          15497  15497    15497
# 2011     15622          15637  15637    15637
# 2012     14003          14092  14092    14092

# %%
year_count.ID.plot(kind='bar',figsize=(10,7))
plt.xlabel('year')
plt.ylabel('number of crime made')
# Out:
# Text(0, 0.5, 'number of crime made')

# %% [markdown]
# ###
#
#
#
#
# ### 6.)   Crimes for which more arrests were made are in the first half of the time period or the second half of the time period?
# (Note that the time period is from 2001 to 2012, so the middle of the time period is the beginning of 2007.)

# %%
year_wise_arrestmade = year_as_index[year_as_index.Arrest==True]

# %%
year_wise_arrestmade[year_wise_arrestmade.index<2007].ID.count()  ## 2001 to 2006
# Out:
# 10588

# %%
year_wise_arrestmade[year_wise_arrestmade.index>2006].ID.count()  ## 2007 to 2012
# Out:
# 4948

# %% [markdown]
# ###
#
#
#
# ###  7.)   For what proportion of motor vehicle thefts in 2001 was an arrest made?
# Note: in this question and many others in the course, we are asking for an answer as a proportion. Therefore, your answer should take a value between 0 and 1

# %%
year_as_index.head()
# Out:
#       Unnamed: 0       ID                Date            LocationDescription  \
# Year
# 2012           0  8951354 2012-12-31 23:15:00                         STREET
# 2012           1  8951141 2012-12-31 22:00:00                         STREET
# 2012           2  8952745 2012-12-31 22:00:00  RESIDENTIAL YARD (FRONT/BACK)
# 2012           3  8952223 2012-12-31 22:00:00                         STREET
# 2012           4  8951608 2012-12-31 21:30:00                         STREET
#
#       Arrest  Domestic  Beat District CommunityArea  Month  weekday
# Year
# 2012   False     False   623        6            69     12        0
# 2012   False     False  1213       12            24     12        0
# 2012   False     False  1622       16            11     12        0
# 2012   False     False   724        7            67     12        0
# 2012   False     False   211        2            35     12        0

# %%
groupby_year = year_as_index.groupby('Year')

# %%
groupby_year.head()
# Out:
#       Unnamed: 0       ID                Date             LocationDescription  \
# Year
# 2012           0  8951354 2012-12-31 23:15:00                          STREET
# 2012           1  8951141 2012-12-31 22:00:00                          STREET
# 2012           2  8952745 2012-12-31 22:00:00   RESIDENTIAL YARD (FRONT/BACK)
# 2012           3  8952223 2012-12-31 22:00:00                          STREET
# 2012           4  8951608 2012-12-31 21:30:00                          STREET
# 2011       14092  8423873 2011-12-31 23:00:00                          STREET
# 2011       14093  8465326 2011-12-31 23:00:00                          STREET
# 2011       14094  8422363 2011-12-31 22:30:00                          STREET
# 2011       14095  8427059 2011-12-31 22:00:00                          STREET
# 2011       14096  8421392 2011-12-31 22:00:00                          STREET
# 2010       29729  7869723 2010-12-31 23:30:00                          STREET
# 2010       29730  7869932 2010-12-31 22:00:00                           ALLEY
# 2010       29731  7869620 2010-12-31 21:30:00  PARKING LOT/GARAGE(NON.RESID.)
# 2010       29732  7879538 2010-12-31 21:00:00                          STREET
# 2010       29733  7872066 2010-12-31 21:00:00                          STREET
# 2009       45226  7296861 2009-12-31 23:37:00                          STREET
# 2009       45227  7297251 2009-12-31 23:30:00                          STREET
# 2009       45228  7297008 2009-12-31 22:00:00                          STREET
# 2009       45229  7305329 2009-12-31 22:00:00  PARKING LOT/GARAGE(NON.RESID.)
# 2009       45230  7297689 2009-12-31 21:30:00                          STREET
# 2008       57393  6686313 2008-12-31 23:30:00                          STREET
# 2008       57394  6686145 2008-12-31 23:00:00                          STREET
# 2008       57395  6687798 2008-12-31 22:00:00                          STREET
# 2008       57396  6685992 2008-12-31 21:30:00                          STREET
# 2008       57397  6686114 2008-12-31 21:30:00                          STREET
# 2007       71838  5993831 2007-12-31 23:00:00                          STREET
# 2007       71839  5991695 2007-12-31 22:30:00                          STREET
# 2007       71840  5992891 2007-12-31 22:00:00                          STREET
# 2007       71841  5992729 2007-12-31 22:00:00                          STREET
# 2007       71842  5997054 2007-12-31 22:00:00                          STREET
# 2006       86118  5214773 2006-12-31 23:45:00                     GAS STATION
# 2006       86119  5219787 2006-12-31 22:30:00                          STREET
# 2006       86120  5222914 2006-12-31 22:30:00  PARKING LOT/GARAGE(NON.RESID.)
# 2006       86121  5214315 2006-12-31 21:00:00                          STREET
# 2006       86122  5216136 2006-12-31 21:00:00                          STREET
# 2005      102216  4515760 2005-12-31 23:30:00                          STREET
# 2005      102217  4512858 2005-12-31 23:00:00                          STREET
# 2005      102218  4513972 2005-12-31 23:00:00                          STREET
# 2005      102219  4536278 2005-12-31 23:00:00                     GAS STATION
# 2005      102220  4513949 2005-12-31 23:00:00                          STREET
# 2004      118700  3732853 2004-12-31 23:59:00                          STREET
# 2004      118701  3731166 2004-12-31 23:30:00                          STREET
# 2004      118702  3732440 2004-12-31 22:30:00                          STREET
# 2004      118703  3732486 2004-12-31 22:00:00                          STREET
# 2004      118704  3730413 2004-12-31 21:00:00          DRIVEWAY - RESIDENTIAL
# 2003      135562  3113549 2003-12-31 22:45:00  PARKING LOT/GARAGE(NON.RESID.)
# 2003      135563  3114773 2003-12-31 22:00:00                          STREET
# 2003      135564  3113660 2003-12-31 22:00:00                          STREET
# 2003      135565  3113948 2003-12-31 21:36:00                          STREET
# 2003      135566  3116259 2003-12-31 20:45:00                 VACANT LOT/LAND
# 2002      152219  2523047 2002-12-31 23:30:00                          STREET
# 2002      152220  2525182 2002-12-31 22:30:00                          STREET
# 2002      152221  2526462 2002-12-31 22:00:00                          STREET
# 2002      152222  2522352 2002-12-31 22:00:00                          STREET
# 2002      152223  2523490 2002-12-31 21:30:00                          STREET
# 2001      170972  1918000 2001-12-31 23:00:00                          STREET
# 2001      170973  1919009 2001-12-31 23:00:00                          STREET
# 2001      170974  1917192 2001-12-31 22:40:00                          STREET
# 2001      170975  1917767 2001-12-31 22:15:00                          STREET
# 2001      170976  1917193 2001-12-31 22:15:00                          STREET
#
#       Arrest  Domestic  Beat District CommunityArea  Month  weekday
# Year
# 2012   False     False   623        6            69     12        0
# 2012   False     False  1213       12            24     12        0
# 2012   False     False  1622       16            11     12        0
# 2012   False     False   724        7            67     12        0
# 2012   False     False   211        2            35     12        0
# 2011   False     False  1824       18             8     12        5
# 2011   False     False  1322       13            24     12        5
# 2011   False     False   911        9            63     12        5
# 2011   False     False   522        5            53     12        5
# 2011   False     False   732        7            69     12        5
# 2010   False     False  1511       15            25     12        4
# 2010   False     False  1133       11            26     12        4
# 2010   False     False  1821       18             8     12        4
# 2010   False     False  1233       12            31     12        4
# 2010   False     False  1531       15            25     12        4
# 2009   False     False  2222       22            73     12        3
# 2009   False     False   421        4            43     12        3
# 2009   False     False   824        8            66     12        3
# 2009   False     False  1824       18             8     12        3
# 2009   False     False  1633       16            15     12        3
# 2008   False     False  1433       14            24     12        2
# 2008   False     False   611        6            71     12        2
# 2008   False     False   725        7            67     12        2
# 2008   False     False  1211       12            28     12        2
# 2008   False     False  1112       11            23     12        2
# 2007   False     False   222        2            38     12        0
# 2007   False     False  1424       14            24     12        0
# 2007   False     False   832        8            66     12        0
# 2007   False     False   824        8            63     12        0
# 2007   False     False   823        8            66     12        0
# 2006   False     False  1322       13            24     12        6
# 2006   False     False  1623       16            15     12        6
# 2006   False     False   132        1            33     12        6
# 2006   False     False  1431       14            22     12        6
# 2006   False     False   821        8            57     12        6
# 2005   False     False  2514       25            19     12        5
# 2005   False     False   912        9            58     12        5
# 2005   False     False   414        4            43     12        5
# 2005   False     False   511        5            50     12        5
# 2005   False     False  1622       16            11     12        5
# 2004   False     False  2413       24             2     12        4
# 2004    True     False  1522       15            25     12        4
# 2004   False     False  1032       10            30     12        4
# 2004   False     False   621        6            71     12        4
# 2004   False     False  2233       22            49     12        4
# 2003    True     False   833        8            64     12        2
# 2003   False     False   711        7            68     12        2
# 2003   False     False   413        4            48     12        2
# 2003    True     False   533        5            54     12        2
# 2003   False     False  2123        2            39     12        2
# 2002   False     False  1431      NaN            22     12        1
# 2002   False     False  1523      NaN            25     12        1
# 2002   False     False   712      NaN            68     12        1
# 2002   False     False  2514       25            19     12        1
# 2002   False     False  2423      NaN             1     12        1
# 2001   False     False  1531      NaN           NaN     12        0
# 2001   False     False  1431      NaN           NaN     12        0
# 2001    True     False   824      NaN           NaN     12        0
# 2001   False     False   233      NaN           NaN     12        0
# 2001   False     False   633      NaN           NaN     12        0

# %%
total_crime_by_year = groupby_year.count()
total_crime_by_year
# Out:
#       Unnamed: 0     ID   Date  LocationDescription  Arrest  Domestic   Beat  \
# Year
# 2001       20669  20669  20669                20669   20669     20669  20669
# 2002       18753  18753  18753                18753   18753     18753  18753
# 2003       16657  16657  16657                16657   16657     16657  16657
# 2004       16862  16862  16862                16862   16862     16862  16862
# 2005       16484  16484  16484                16484   16484     16484  16484
# 2006       16098  16098  16098                16098   16098     16098  16098
# 2007       14280  14280  14280                14280   14280     14280  14280
# 2008       14445  14445  14445                14445   14445     14445  14445
# 2009       12167  12167  12167                12167   12167     12167  12167
# 2010       15497  15497  15497                15497   15497     15497  15497
# 2011       15637  15637  15637                15637   15637     15637  15637
# 2012       14092  14092  14092                14092   14092     14092  14092
#
#       District  CommunityArea  Month  weekday
# Year
# 2001       122            586  20669    20669
# 2002       494          14236  18753    18753
# 2003     12977          16657  16657    16657
# 2004     16824          16861  16862    16862
# 2005     16403          16484  16484    16484
# 2006     16069          16097  16098    16098
# 2007     14271          14280  14280    14280
# 2008     14280          14445  14445    14445
# 2009     12040          12166  12167    12167
# 2010     15484          15497  15497    15497
# 2011     15622          15637  15637    15637
# 2012     14003          14092  14092    14092

# %%
groupby_year_arrestmade = year_as_index[year_as_index.Arrest==True].groupby('Year')

# %%
total_arrest_by_year = groupby_year_arrestmade.count()
total_arrest_by_year
# Out:
#       Unnamed: 0    ID  Date  LocationDescription  Arrest  Domestic  Beat  \
# Year
# 2001        2152  2152  2152                 2152    2152      2152  2152
# 2002        2115  2115  2115                 2115    2115      2115  2115
# 2003        1798  1798  1798                 1798    1798      1798  1798
# 2004        1693  1693  1693                 1693    1693      1693  1693
# 2005        1528  1528  1528                 1528    1528      1528  1528
# 2006        1302  1302  1302                 1302    1302      1302  1302
# 2007        1212  1212  1212                 1212    1212      1212  1212
# 2008        1020  1020  1020                 1020    1020      1020  1020
# 2009         840   840   840                  840     840       840   840
# 2010         701   701   701                  701     701       701   701
# 2011         625   625   625                  625     625       625   625
# 2012         550   550   550                  550     550       550   550
#
#       District  CommunityArea  Month  weekday
# Year
# 2001         3             36   2152     2152
# 2002        23           1506   2115     2115
# 2003      1415           1798   1798     1798
# 2004      1691           1693   1693     1693
# 2005      1523           1528   1528     1528
# 2006      1301           1302   1302     1302
# 2007      1212           1212   1212     1212
# 2008      1013           1020   1020     1020
# 2009       833            839    840      840
# 2010       700            701    701      701
# 2011       625            625    625      625
# 2012       547            550    550      550

# %%
total_arrest_by_year.ID.plot(kind='bar',figsize=(5,7))
plt.xlabel('year')
plt.ylabel('number of arrest made')
# Out:
# Text(0, 0.5, 'number of arrest made')

# %%
arrest_proportion = total_arrest_by_year.ID/total_crime_by_year.ID
arrest_proportion
# Out:
# Year
# 2001    0.104117
# 2002    0.112782
# 2003    0.107943
# 2004    0.100403
# 2005    0.092696
# 2006    0.080880
# 2007    0.084874
# 2008    0.070613
# 2009    0.069039
# 2010    0.045235
# 2011    0.039969
# 2012    0.039029
# Name: ID, dtype: float64

# %%
arrest_proportion.plot(kind='bar',figsize=(5,7))
plt.xlabel('year')
plt.ylabel('proportion of arrest made against crime happned')
# Out:
# Text(0, 0.5, 'proportion of arrest made against crime happned')

# %% [markdown]
# ###
#
#
#
#
# ### 8.)  Which locations are the top five locations for motor vehicle thefts, excluding the "Other" category?

# %%
location_as_index = df.set_index('LocationDescription')
location_as_index.head()
# Out:
#                                Unnamed: 0       ID                Date  \
# LocationDescription
# STREET                                  0  8951354 2012-12-31 23:15:00
# STREET                                  1  8951141 2012-12-31 22:00:00
# RESIDENTIAL YARD (FRONT/BACK)           2  8952745 2012-12-31 22:00:00
# STREET                                  3  8952223 2012-12-31 22:00:00
# STREET                                  4  8951608 2012-12-31 21:30:00
#
#                                Arrest  Domestic  Beat District CommunityArea  \
# LocationDescription
# STREET                          False     False   623        6            69
# STREET                          False     False  1213       12            24
# RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16            11
# STREET                          False     False   724        7            67
# STREET                          False     False   211        2            35
#
#                                Year  Month  weekday
# LocationDescription
# STREET                         2012     12        0
# STREET                         2012     12        0
# RESIDENTIAL YARD (FRONT/BACK)  2012     12        0
# STREET                         2012     12        0
# STREET                         2012     12        0

# %%
groupby_location = location_as_index.groupby('LocationDescription')
groupby_location.head()
# Out:
#                                  Unnamed: 0       ID                Date  \
# LocationDescription
# STREET                                    0  8951354 2012-12-31 23:15:00
# STREET                                    1  8951141 2012-12-31 22:00:00
# RESIDENTIAL YARD (FRONT/BACK)             2  8952745 2012-12-31 22:00:00
# STREET                                    3  8952223 2012-12-31 22:00:00
# STREET                                    4  8951608 2012-12-31 21:30:00
# ...                                     ...      ...                 ...
# OTHER COMMERCIAL TRANSPORTATION      178440  1778216 2001-09-08 12:25:00
# LAKEFRONT/WATERFRONT/RIVERBANK       182983  1601131 2001-06-24 04:15:00
# DAY CARE CENTER                      188175  1426823 2001-03-15 14:45:00
# SAVINGS AND LOAN                     189345  1386720 2001-02-18 04:02:00
# CLEANING STORE                       190779  1339044 2001-01-18 19:00:00
#
#                                  Arrest  Domestic  Beat District  \
# LocationDescription
# STREET                            False     False   623        6
# STREET                            False     False  1213       12
# RESIDENTIAL YARD (FRONT/BACK)     False     False  1622       16
# STREET                            False     False   724        7
# STREET                            False     False   211        2
# ...                                 ...       ...   ...      ...
# OTHER COMMERCIAL TRANSPORTATION    True     False   411      NaN
# LAKEFRONT/WATERFRONT/RIVERBANK    False     False  2333      NaN
# DAY CARE CENTER                   False     False   833      NaN
# SAVINGS AND LOAN                  False     False  1821      NaN
# CLEANING STORE                    False     False  1522      NaN
#
#                                 CommunityArea  Year  Month  weekday
# LocationDescription
# STREET                                     69  2012     12        0
# STREET                                     24  2012     12        0
# RESIDENTIAL YARD (FRONT/BACK)              11  2012     12        0
# STREET                                     67  2012     12        0
# STREET                                     35  2012     12        0
# ...                                       ...   ...    ...      ...
# OTHER COMMERCIAL TRANSPORTATION           NaN  2001      9        5
# LAKEFRONT/WATERFRONT/RIVERBANK            NaN  2001      6        6
# DAY CARE CENTER                           NaN  2001      3        3
# SAVINGS AND LOAN                          NaN  2001      2        6
# CLEANING STORE                            NaN  2001      1        3
#
# [341 rows x 11 columns]

# %%
count_by_location = groupby_location.ID.count().sort_values(ascending=False)
count_by_location
# Out:
# LocationDescription
# STREET                                         156564
# PARKING LOT/GARAGE(NON.RESID.)                  14852
# OTHER                                            4573
# ALLEY                                            2308
# GAS STATION                                      2111
#                                                 ...
# NEWSSTAND                                           1
# AIRPORT EXTERIOR - SECURE AREA                      1
# AIRPORT BUILDING NON-TERMINAL - SECURE AREA         1
# CTA TRAIN                                           1
# JAIL / LOCK-UP FACILITY                             1
# Name: ID, Length: 78, dtype: int64

# %% [markdown]
# #####  Top 25 location where most frequently crime are made

# %%
count_by_location.head(25)
# Out:
# LocationDescription
# STREET                             156564
# PARKING LOT/GARAGE(NON.RESID.)      14852
# OTHER                                4573
# ALLEY                                2308
# GAS STATION                          2111
# DRIVEWAY - RESIDENTIAL               1675
# RESIDENTIAL YARD (FRONT/BACK)        1536
# RESIDENCE                            1302
# RESIDENCE-GARAGE                     1176
# VACANT LOT/LAND                       985
# VEHICLE NON-COMMERCIAL                817
# SIDEWALK                              462
# CHA PARKING LOT/GROUNDS               405
# AIRPORT/AIRCRAFT                      363
# POLICE FACILITY/VEH PARKING LOT       266
# PARK PROPERTY                         255
# SCHOOL, PUBLIC, GROUNDS               206
# APARTMENT                             184
# SPORTS ARENA/STADIUM                  166
# CTA GARAGE / OTHER PROPERTY           148
# COMMERCIAL / BUSINESS OFFICE          126
# HOTEL/MOTEL                           124
# SCHOOL, PUBLIC, BUILDING              114
# HOSPITAL BUILDING/GROUNDS             101
# GROCERY FOOD STORE                     80
# Name: ID, dtype: int64

# %% [markdown]
# ###
#
#
#
#
#
# ### 9.)  Create a subset of your data, only taking observations for which the theft happened in one of these five locations, and call this new data set "Top5". How many observations are in Top5?

# %%
top5_location = ['STREET','PARKING LOT/GARAGE(NON.RESID.)','ALLEY','GAS STATION','DRIVEWAY - RESIDENTIAL']

Top5 = df[df.LocationDescription.isin(top5_location)]

# %%
Top5
# Out:
#         Unnamed: 0       ID                Date LocationDescription  Arrest  \
# 0                0  8951354 2012-12-31 23:15:00              STREET   False
# 1                1  8951141 2012-12-31 22:00:00              STREET   False
# 3                3  8952223 2012-12-31 22:00:00              STREET   False
# 4                4  8951608 2012-12-31 21:30:00              STREET   False
# 5                5  8950793 2012-12-31 20:30:00              STREET    True
# ...            ...      ...                 ...                 ...     ...
# 191636      191636  1310068 2001-01-01 00:05:00              STREET   False
# 191637      191637  1313404 2001-01-01 00:01:00              STREET   False
# 191638      191638  1313442 2001-01-01 00:01:00              STREET   False
# 191639      191639  1563324 2001-01-01 00:01:00              STREET   False
# 191640      191640  1310463 2001-01-01 00:01:00              STREET   False
#
#         Domestic  Beat District CommunityArea  Year  Month  weekday
# 0          False   623        6            69  2012     12        0
# 1          False  1213       12            24  2012     12        0
# 3          False   724        7            67  2012     12        0
# 4          False   211        2            35  2012     12        0
# 5          False  2521       25            19  2012     12        0
# ...          ...   ...      ...           ...   ...    ...      ...
# 191636     False  1123      NaN           NaN  2001      1        0
# 191637     False  2023      NaN           NaN  2001      1        0
# 191638     False   911      NaN           NaN  2001      1        0
# 191639     False  1712      NaN           NaN  2001      1        0
# 191640     False  1911      NaN           NaN  2001      1        0
#
# [177510 rows x 12 columns]

# %% [markdown]
# ###### Top5 give total 177510 observation

# %% [markdown]
# ###
#
#
#
#
# ### 10.)   On which day of the week do the most motor vehicle thefts at gas stations happen?

# %%
weekday_as_index.head()
# Out:
#          Unnamed: 0       ID                Date  \
# weekday
# 0                 0  8951354 2012-12-31 23:15:00
# 0                 1  8951141 2012-12-31 22:00:00
# 0                 2  8952745 2012-12-31 22:00:00
# 0                 3  8952223 2012-12-31 22:00:00
# 0                 4  8951608 2012-12-31 21:30:00
#
#                    LocationDescription  Arrest  Domestic  Beat District  \
# weekday
# 0                               STREET   False     False   623        6
# 0                               STREET   False     False  1213       12
# 0        RESIDENTIAL YARD (FRONT/BACK)   False     False  1622       16
# 0                               STREET   False     False   724        7
# 0                               STREET   False     False   211        2
#
#         CommunityArea  Year  Month
# weekday
# 0                  69  2012     12
# 0                  24  2012     12
# 0                  11  2012     12
# 0                  67  2012     12
# 0                  35  2012     12

# %%
weekday_as_index[weekday_as_index.LocationDescription=='GAS STATION'].index.value_counts()
# Out:
# 5    338
# 6    336
# 4    332
# 3    282
# 0    280
# 2    273
# 1    270
# Name: weekday, dtype: int64

# %% [markdown]
# ##### Ans :- saturday

# %% [markdown]
# #####  By this method we can find information about any location at perticuler day

# %% [markdown]
# #                        THANK YOU
